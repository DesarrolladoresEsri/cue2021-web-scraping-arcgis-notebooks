# %%
import requests
import pytz
from datetime import datetime
from arcgis.gis import GIS

# %%
gis = GIS("home")

# %%
consulta_url_estaciones = requests.get("https://www.hidromet.com.pa/es/estaciones-satelitales-data2?sensor=LLUVIA")
datos_url_estaciones = consulta_url_estaciones.json()
datos_url_estaciones
# Out:
# {'estaciones': {'ALTO_PACORA': {'latitud': '9.2456',
#    'longitud': '-79.3497',
#    'nombre': 'ALTO PACORA',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '29/07/2021 10:15 AM',
#    'numero_estacion': '146003'},
#   'AMBROYA': {'latitud': '8.9311',
#    'longitud': '-78.5650',
#    'nombre': 'AMBROYA',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '148040'},
#   'BELEN_2': {'latitud': '8.8831',
#    'longitud': '-80.8692',
#    'nombre': 'BELEN 2',
#    'sensor_valor': '0.5 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '103002'},
#   'BOQUETE': {'latitud': '8.7550',
#    'longitud': '-82.4314',
#    'nombre': 'BOQUETE',
#    'sensor_valor': '8 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '108053'},
#   'BUENA VISTA': {'latitud': '9.2772',
#    'longitud': '-79.7000',
#    'nombre': 'BUENA VISTA',
#    'sensor_valor': '2.5 mm',
#    'sensor_fecha': '4/08/2021 12:45 AM',
#    'numero_estacion': '115126'},
#   'CAISAN_CENTRO': {'latitud': '8.7631',
#    'longitud': '-82.7933',
#    'nombre': 'CAISAN CENTRO',
#    'sensor_valor': '39 mm',
#    'sensor_fecha': '4/08/2021 12:45 AM',
#    'numero_estacion': '102007'},
#   'CALOBEVORA': {'latitud': '8.7875',
#    'longitud': '-81.2097',
#    'nombre': 'CALOBEVORA',
#    'sensor_valor': '14.5 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '97001'},
#   'CERRO_PUNTA': {'latitud': '8.8575',
#    'longitud': '-82.5881',
#    'nombre': 'CERRO PUNTA',
#    'sensor_valor': '13.5 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '102040'},
#   'CHANGUINOLA_2': {'latitud': '8.9303',
#    'longitud': '-82.6900',
#    'nombre': 'CHANGUINOLA 2',
#    'sensor_valor': '15.5 mm',
#    'sensor_fecha': '4/08/2021 01:15 AM',
#    'numero_estacion': '91029'},
#   'CHANGUINOLA_SP_01': {'latitud': '9.2378',
#    'longitud': '-82.4961',
#    'nombre': 'CHANGUINOLA SP 01',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '91034'},
#   'CHICO_CORDILLERA_ARRIBA': {'latitud': '8.7522',
#    'longitud': '-82.6103',
#    'nombre': 'CHICO CORDILLERA ARRIBA',
#    'sensor_valor': '1 mm',
#    'sensor_fecha': '3/08/2021 11:00 PM',
#    'numero_estacion': '106013'},
#   'CHIMAN 2': {'latitud': '8.7181',
#    'longitud': '-78.6339',
#    'nombre': 'CHIMAN 2',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '150006'},
#   'CND': {'latitud': '9.0369',
#    'longitud': '-79.5256',
#    'nombre': 'CND',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '142042'},
#   'COCHEA DOLEGA': {'latitud': '8.5844',
#    'longitud': '-82.4136',
#    'nombre': 'COCHEA DOLEGA',
#    'sensor_valor': '5 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '108059'},
#   'CUANGO': {'latitud': '9.5444',
#    'longitud': '-79.3033',
#    'nombre': 'CUANGO',
#    'sensor_valor': '1 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '117017'},
#   'CUIPO': {'latitud': '9.0633',
#    'longitud': '-80.0739',
#    'nombre': 'CUIPO',
#    'sensor_valor': '0.1 mm',
#    'sensor_fecha': '21/07/2021 08:30 AM',
#    'numero_estacion': '115124'},
#   'EL_LLANO_ARRAIJAN': {'latitud': '8.9342',
#    'longitud': '-79.6606',
#    'nombre': 'EL LLANO ARRAIJAN',
#    'sensor_valor': '0.5 mm',
#    'sensor_fecha': '4/08/2021 01:15 AM',
#    'numero_estacion': '140007'},
#   'EL_NARANJAL': {'latitud': '9.1289',
#    'longitud': '-79.2297',
#    'nombre': 'EL NARANJAL',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '148049'},
#   'FORTUNA_CASA_CONTROL': {'latitud': '8.6792',
#    'longitud': '-82.2617',
#    'nombre': 'FORTUNA CASA CONTROL',
#    'sensor_valor': '3.5 mm',
#    'sensor_fecha': '4/08/2021 01:15 AM',
#    'numero_estacion': '108042'},
#   'GARACHINE2': {'latitud': '8.0650',
#    'longitud': '-78.3664',
#    'nombre': 'GARACHINE2',
#    'sensor_valor': '3 mm',
#    'sensor_fecha': '4/08/2021 12:45 AM',
#    'numero_estacion': '162009'},
#   'ICACAL': {'latitud': '9.1989',
#    'longitud': '-80.1519',
#    'nombre': 'ICACAL',
#    'sensor_valor': '6 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '113008'},
#   'ISLA_BOCAS': {'latitud': '9.3403',
#    'longitud': '-82.2447',
#    'nombre': 'ISLA BOCAS',
#    'sensor_valor': '7.5 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '93002'},
#   'LAS_MARTINAS': {'latitud': '8.3436',
#    'longitud': '-82.5597',
#    'nombre': 'LAS MARTINAS',
#    'sensor_valor': '14.5 mm',
#    'sensor_fecha': '4/08/2021 01:15 AM',
#    'numero_estacion': '106012'},
#   'LLANO_CARTI': {'latitud': '9.3081',
#    'longitud': '-78.9867',
#    'nombre': 'LLANO CARTI',
#    'sensor_valor': '1 mm',
#    'sensor_fecha': '4/08/2021 12:45 AM',
#    'numero_estacion': '148033'},
#   'LOS CHORROS': {'latitud': '8.7622',
#    'longitud': '-80.1272',
#    'nombre': 'LOS CHORROS',
#    'sensor_valor': '3 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '111008'},
#   'MARIATO': {'latitud': '7.6469',
#    'longitud': '-80.9978',
#    'nombre': 'MARIATO',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '122008'},
#   'PIEDRA_CANDELA': {'latitud': '8.8747',
#    'longitud': '-82.7786',
#    'nombre': 'PIEDRA CANDELA',
#    'sensor_valor': '4 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '102041'},
#   'PIGANDI': {'latitud': '8.9578',
#    'longitud': '-78.1367',
#    'nombre': 'PIGANDI',
#    'sensor_valor': '50 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '148038'},
#   'PLAYON_CHICO': {'latitud': '9.3081',
#    'longitud': '-78.2342',
#    'nombre': 'PLAYON CHICO',
#    'sensor_valor': '51.5 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '121014'},
#   'POTRERILLOS': {'latitud': '8.7011',
#    'longitud': '-82.4972',
#    'nombre': 'POTRERILLOS',
#    'sensor_valor': '8.5 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '108052'},
#   'QUEBRADA BIJAO': {'latitud': '8.7450',
#    'longitud': '-82.1656',
#    'nombre': 'QUEBRADA BIJAO',
#    'sensor_valor': '21 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '108020'},
#   'QUEREVALO 2': {'latitud': '8.3506',
#    'longitud': '-82.5125',
#    'nombre': 'QUEREVALO 2',
#    'sensor_valor': '2 mm',
#    'sensor_fecha': '4/08/2021 12:45 AM',
#    'numero_estacion': '106014'},
#   'RATON': {'latitud': '8.3347',
#    'longitud': '-81.8192',
#    'nombre': 'RATON',
#    'sensor_valor': '9 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '112014'},
#   'RIO_HORNITOS_HORNITOS': {'latitud': '8.7183',
#    'longitud': '-82.2283',
#    'nombre': 'RIO HORNITOS HORNITOS',
#    'sensor_valor': '6.5 mm',
#    'sensor_fecha': '4/08/2021 01:15 AM',
#    'numero_estacion': '108058'},
#   'SAMBU_BOCA_DE_TRAMPA': {'latitud': '7.9367',
#    'longitud': '-78.1417',
#    'nombre': 'SAMBU BOCA DE TRAMPA',
#    'sensor_valor': '9 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '162008'},
#   'SAN_LUCAS': {'latitud': '9.0064',
#    'longitud': '-80.5653',
#    'nombre': 'SAN LUCAS',
#    'sensor_valor': '22.5 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '105028'},
#   'SANTA_FE': {'latitud': '8.6664',
#    'longitud': '-78.1383',
#    'nombre': 'SANTA FE',
#    'sensor_valor': '0.5 mm',
#    'sensor_fecha': '4/08/2021 12:30 AM',
#    'numero_estacion': '152006'},
#   'SE CHANGUINOLA': {'latitud': '9.4075',
#    'longitud': '-82.5633',
#    'nombre': 'SE CHANGUINOLA',
#    'sensor_valor': '0 mm',
#    'sensor_fecha': '4/08/2021 12:15 AM',
#    'numero_estacion': '91033'},
#   'SE LLANO SANCHEZ': {'latitud': '8.1947',
#    'longitud': '-80.6981',
#    'nombre': 'SE LLANO SANCHEZ',
#    'sensor_valor': '0.5 mm',
#    'sensor_fecha': '4/08/2021 01:00 AM',
#    'numero_estacion': '134039'}}}

# %%
timezone = pytz.timezone("America/Panama")

def transformar_datos_url(datos_url):
    datos = []
    for k, v in datos_url_estaciones['estaciones'].items():
        sensor_fecha = datetime.strptime(v['sensor_fecha'], '%d/%m/%Y %I:%M %p')
        sensor_fecha_tz = timezone.localize(sensor_fecha)
        dato = {'geometry': {
                    'x': float(v['longitud']),
                    'y': float(v['latitud']),
                    'spatialReference': {'wkid': 4326, 'latestWkid': 4326}
                },
                'attributes': {
                    'numero_estacion': v['numero_estacion'],
                    'nombre_1': k,
                    'nombre_2': v['nombre'],
                    'latitud': float(v['latitud']),
                    'longitud': float(v['longitud']),
                    'sensor_valor': float(v['sensor_valor'][:-3]),
                    'sensor_fecha': sensor_fecha_tz}
                }
        datos.append(dato)
        
    return datos

# %%
features = transformar_datos_url(datos_url_estaciones)
features[0]
# Out:
# {'geometry': {'x': -79.3497,
#   'y': 9.2456,
#   'spatialReference': {'wkid': 4326, 'latestWkid': 4326}},
#  'attributes': {'numero_estacion': '146003',
#   'nombre_1': 'ALTO_PACORA',
#   'nombre_2': 'ALTO PACORA',
#   'latitud': 9.2456,
#   'longitud': -79.3497,
#   'sensor_valor': 0.0,
#   'sensor_fecha': datetime.datetime(2021, 7, 29, 10, 15, tzinfo=<DstTzInfo 'America/Panama' EST-1 day, 19:00:00 STD>)}}

# %%
item = gis.content.get('a76ed3d23043433596db6b836c24cebb')
layer = item.layers[0]

# %%
layer.edit_features(adds=features)
# Out:
# {'addResults': [{'objectId': 79,
#    'uniqueId': 79,
#    'globalId': None,
#    'success': True},
